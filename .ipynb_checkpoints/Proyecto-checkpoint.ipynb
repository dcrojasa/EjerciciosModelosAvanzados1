# %% [markdown]
# # Proyecto análisis serie de tiempo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
##
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
df = pd.read_csv('../EjerciciosModelosAvanzados1/BaseTransporte 1.csv', sep=';')
df.head()
# Out:
#   SiglaEmpresa      Fecha Origen  NumerodeVuelos HorasBloque  Sillas  \
# 0          VVC  1/03/2020    BOG              54      117,19   10072
# 1          RPB  1/03/2020    BOG              12       28,15    2232
# 2          KRE  1/03/2020    BOG               4        7,65       0
# 3          AVA  1/03/2020    BOG              49      107,77    9419
# 4          AVA  1/03/2020    BOG              33       72,56    4949
#
#    CargaOfrecidaKg  PasajerosABordo Distancia     Ruta  Millas   Ano  Mes
# 0             7074                0       NaN  ADZ-BOG     749  2020  mar
# 1             1527                0       NaN  ADZ-BOG     749  2020  mar
# 2                0                0       NaN  ADZ-BOG     749  2020  mar
# 3             6587                0       NaN  ADZ-BOG     749  2020  mar
# 4             2090                0       NaN  ADZ-BOG     749  2020  mar

# %%
# seleccionar y convertir a fecha el indice
df1 = df[['Fecha','Sillas']]
df1.set_index('Fecha', inplace=True)
df1.head()
# Out:
#            Sillas
# Fecha
# 1/03/2020   10072
# 1/03/2020    2232
# 1/03/2020       0
# 1/03/2020    9419
# 1/03/2020    4949

# %%
# Grafico de los datos
df1.plot(figsize=(50,15), linewidth=1, fontsize=40, color=('b'))
plt.xlabel('Tiempo', fontsize=50)
plt.suptitle('Serie de datos - Sillas', fontsize=40)
plt.legend(prop={'size':40});

# %%
# Anaisis de tendencia
df1[['Sillas']].rolling(200).mean().plot(figsize=(50,15), linewidth=1, fontsize=40, color=('b'))
plt.xlabel('Tiempo', fontsize=50)
plt.suptitle('Tendencia de datos', fontsize=40)
plt.legend(prop={'size':40});

# %%
# Analisis estacionalidad
df1.diff().plot(figsize=(50,15), linewidth=1, fontsize=40, color=('b'))
plt.xlabel('Tiempo', fontsize=50)
plt.suptitle('Estacionalidad', fontsize=40)
plt.legend(prop={'size':40});

# %%
Prueba = df1.loc[2,['Fecha']]
Prueba
fecha_dt = datetime.strptime(Prueba, '%d/%m/%Y')
print(fecha_dt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-cc735418ece5> in <module>
#       1 Prueba = df1.loc[2,['Fecha']]
#       2 Prueba
# ----> 3 fecha_dt = datetime.strptime(Prueba, '%d/%m/%Y')
#       4 print(fecha_dt)
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
from datetime import datetime

#una_fecha = '20/04/2019'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d45ae457c618> in <module>
#       2
#       3 #una_fecha = '20/04/2019'
# ----> 4 fecha_dt = datetime.strptime(df[['Fecha']], '%d/%m/%Y')
#       5 print(fecha_dt)
#
# TypeError: strptime() argument 1 must be str, not DataFrame
