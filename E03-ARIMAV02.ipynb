# %% [markdown]
# # Exercise 03 - Autoregressive Integrated Moving Average Models
#
# - The result will be evaluated from a report in Jupiter, which must be found in a public GitHub repository.
# - The project must be carried out in the groups assigned in class.
# - Use clear and rigorous procedures.
# - Due date: 22, 2020, 11:59 pm, through Sicua + (Upload repository link)
#
# # 03.1 - Plot the ACF and PACF of the 4 series in data_arma.csv
# ### Try to say to which AR or MA process each series belong

# %%
import pandas as pd
df = pd.read_csv('C:/Users/Carlos P/Projects/Data/data_arma.csv', index_col=0)
df.head()
# Out:
#         ts1       ts2       ts3       ts4
# 0  0.533570 -0.126804 -0.802837  1.812825
# 1  1.240130  1.314360 -0.595602  0.042764
# 2  1.618598  1.405994  0.127180 -1.759427
# 3  1.140465  3.132621  0.958586 -0.456798
# 4  0.481561  3.179083  0.164598 -1.254790

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 4 columns):
# ts1    500 non-null float64
# ts2    500 non-null float64
# ts3    500 non-null float64
# ts4    500 non-null float64
# dtypes: float64(4)
# memory usage: 19.5 KB

# %% [markdown]
# # 03.2 - Using the shampoo dataset:
# ## Find the parameters p, d q that minimizes the mse of the rolling forecast

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def parser(x):
    return pd.datetime.strptime('190'+x, '%Y-%m')
 
series = pd.read_csv('C:/Users/Carlos P/Projects/Data/shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
print(series.head())
series.plot(figsize=(10, 10));
# Out:
# Month
# 1901-01-01    266.0
# 1901-02-01    145.9
# 1901-03-01    183.1
# 1901-04-01    119.3
# 1901-05-01    180.3
# Name: Sales, dtype: float64

# %%
X = series.values
size = int(len(X) * 0.66)train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()

# %%
# fit model
    # No todas las combinaciones de los parámetros son factibles.
for ma in range(7):
    for ar in range(ma + 1, 8):
        # Predicciones y sobre test
        X = series.values
        size = int(len(X) * 0.66)
        train, test = X[0:size], X[size:len(X)]
        history = [x for x in train]
        predictions = list()
        for t in range(len(test)):
            model = ARIMA(history, order=(ar, 1, ma))
            model_fit = model.fit(disp=0)
            output = model_fit.forecast()
            yhat = output[0]
            predictions.append(yhat)
            obs = test[t]
            history.append(obs)
        error = mean_squared_error(test, predictions)     
        print('p:', ar, '- d: 1 - q:', ma,'- Test MSE: %.3f' % error)
# Out:
# p: 1 - d: 1 - q: 0 - Test MSE: 7121.371
# p: 2 - d: 1 - q: 0 - Test MSE: 5689.928
# p: 3 - d: 1 - q: 0 - Test MSE: 6998.940
# p: 4 - d: 1 - q: 0 - Test MSE: 6649.595
# p: 5 - d: 1 - q: 0 - Test MSE: 6958.324
# p: 6 - d: 1 - q: 0 - Test MSE: 6810.077
# p: 7 - d: 1 - q: 0 - Test MSE: 6523.843
# p: 2 - d: 1 - q: 1 - Test MSE: 7759.707
# p: 3 - d: 1 - q: 1 - Test MSE: 7145.874
# p: 4 - d: 1 - q: 1 - Test MSE: 6796.300
# G:\Anaconda3\lib\site-packages\statsmodels\base\model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# G:\Anaconda3\lib\site-packages\statsmodels\base\model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# G:\Anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# G:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:695: RuntimeWarning: divide by zero encountered in true_divide
#   invmacoefs = -np.log((1-macoefs)/(1+macoefs))
# G:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:668: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# G:\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:669: RuntimeWarning: invalid value encountered in true_divide
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-36-7d7f835fb8c8> in <module>
#      11         for t in range(len(test)):
#      12             model = ARIMA(history, order=(ar, 1, ma))
# ---> 13             model_fit = model.fit(disp=0)
#      14             output = model_fit.forecast()
#      15             yhat = output[0]
#
# G:\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1147                                            method, transparams, solver,
#    1148                                            maxiter, full_output, disp,
# -> 1149                                            callback, start_ar_lags, **kwargs)
#    1150         normalized_cov_params = None  # TODO: fix this?
#    1151         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# G:\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     949                                        maxiter=maxiter,
#     950                                        full_output=full_output, disp=disp,
# --> 951                                        callback=callback, **kwargs)
#     952         params = mlefit.params
#     953
#
# G:\Anaconda3\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     468                                                        callback=callback,
#     469                                                        retall=retall,
# --> 470                                                        full_output=full_output)
#     471
#     472         # NOTE: this is for fit_regularized and should be generalized
#
# G:\Anaconda3\lib\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     217                             disp=disp, maxiter=maxiter, callback=callback,
#     218                             retall=retall, full_output=full_output,
# --> 219                             hess=hessian)
#     220
#     221         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# G:\Anaconda3\lib\site-packages\statsmodels\base\optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     437                                      callback=callback, args=fargs,
#     438                                      bounds=bounds, disp=disp,
# --> 439                                      **extra_kwargs)
#     440
#     441     if full_output:
#
# G:\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# G:\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# G:\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     278     if jac is None:
#     279         def func_and_grad(x):
# --> 280             f = fun(x, *args)
#     281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#
# G:\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# G:\Anaconda3\lib\site-packages\statsmodels\base\model.py in f(params, *args)
#     442
#     443         def f(params, *args):
# --> 444             return -self.loglike(params, *args) / nobs
#     445
#     446         if method == 'newton':
#
# G:\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in loglike(self, params, set_sigma2)
#     770         method = self.method
#     771         if method in ['mle', 'css-mle']:
# --> 772             return self.loglike_kalman(params, set_sigma2)
#     773         elif method == 'css':
#     774             return self.loglike_css(params, set_sigma2)
#
# G:\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in loglike_kalman(self, params, set_sigma2)
#     780         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     781         """
# --> 782         return KalmanFilter.loglike(params, self, set_sigma2)
#     783
#     784     def loglike_css(self, params, set_sigma2=True):
#
# G:\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     219             loglike, sigma2 = kalman_loglike.kalman_loglike_double(
#     220                 y, k, k_ar, k_ma, k_lags, int(nobs),
# --> 221                 Z_mat, R_mat, T_mat)
#     222         elif np.issubdtype(paramsdtype, np.complex128):
#     223             loglike, sigma2 = kalman_loglike.kalman_loglike_complex(
#
# statsmodels\tsa\kalmanf\kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_loglike_double()
#
# statsmodels\tsa\kalmanf\kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_filter_double()
#
# G:\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in pinv(a, rcond)
#    1936         return wrap(res)
#    1937     a = a.conjugate()
# -> 1938     u, s, vt = svd(a, full_matrices=False)
#    1939
#    1940     # discard small singular values
#
# G:\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv)
#    1610
#    1611         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1612         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1613         u = u.astype(result_t, copy=False)
#    1614         s = s.astype(_realType(result_t), copy=False)
#
# G:\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_svd_nonconvergence(err, flag)
#     104
#     105 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 106     raise LinAlgError("SVD did not converge")
#     107
#     108 def _raise_linalgerror_lstsq(err, flag):
#
# LinAlgError: SVD did not converge
